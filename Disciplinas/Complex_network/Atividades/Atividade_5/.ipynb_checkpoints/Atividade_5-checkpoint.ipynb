# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as plt2
import igraph as ig
import networkx as nx
import itertools
import math
import random
from scipy.stats import kde
from networkx.algorithms import bipartite
from sklearn import preprocessing
from sklearn.preprocessing import normalize, MinMaxScaler

# %% [markdown]
# ## Exercício 1) Degree correlation matrix

# %% [markdown]
# ### Using my functions

# %%
#calculating the degree correlation matrix

def dcm_network(g):
    nodes = g.vcount()  #taking the number of nodes
    corr_matrix = np.zeros((nodes,nodes),dtype=int) #creating the matrix with number of nodes
    
    for i in range(nodes): #iterating of all nodes
        deg_i = g.degree(i) # taking node-i degree
        neighbor_deg = [g.degree(k) for k in g.neighbors(i)]  #taking tke degrees of node-i's neighbors
        for j in neighbor_deg:  # setting in matrix the connection between i-node and its neighbors
            corr_matrix[deg_i][j] += 1  
            
    return corr_matrix

# %%
#plotting correlatin matrix

def plot_matrix(corr_,x,y,name_file,name_title):    
    plt.figure(figsize=(12,9))

    sns.heatmap(corr_,vmin=0, vmax=np.max(corr_),cmap="YlGnBu")
    plt.gca().invert_yaxis()
    plt.title('Degree Correlation Matrix ' + name_title)
    plt.xlabel(r'$k_1$')
    plt.ylabel(r'$k_2$')
    plt.xticks(rotation=45)
    plt.xlim(0,x)
    plt.ylim(0,y)
    plt.savefig(name_file, dpi=300)    
    plt.show()

# %%
#Reading network file

g = ig.load('metabolic.edgelist.txt')
g.to_undirected()  # converting to undirected network

# %%
#checking the density of degrees

sns.kdeplot(g.degree())
plt.title('Degree Density Metabolic Network')
plt.xlabel('k')
plt.ylabel(r'$p_k$')
# Out:
# Text(0, 0.5, '$p_k$')

# %%
g.maxdegree()
# Out:
# 638

# %%
corr_matrix = dcm_network(g) #creating the matrix
corr_matrix_norm = corr_matrix/corr_matrix.sum() #normalizing network
plot_matrix(corr_matrix_norm,650,650,'metabolic_matrix.pdf','Metabolic Network Normalized') #plotting the matrix

# %% [markdown]
# #### Testing the functions with a random network

# %%
g_rand = ig.Graph.Erdos_Renyi(n = 300, p = 0.2, directed=False)

# %%
#checking the density of degrees

sns.kdeplot(g_rand.degree())
plt.title('Degree Density Random Network')
plt.xlabel('k')
plt.ylabel(r'$p_k$')
# Out:
# Text(0, 0.5, '$p_k$')

# %%
g_rand.maxdegree()
# Out:
# 77

# %%
#testing a random network

corr_matrix_rand = dcm_network(g_rand) #creating the matrix
corr_matrix_rand_norm = corr_matrix_rand/corr_matrix_rand.sum()  #normalizing network
plot_matrix(corr_matrix_rand_norm,100,100,'random.pdf','Random Network Normalized' ) #plotting the matrix

# %% [markdown]
# ### Using networkx function (*Professor Resolution)

# %%
def dcm_nx(G):
    deg = dict(nx.degree(G)) #taking the degree nodes

    nx.set_node_attributes(G, deg, 'degree')  #setting the new attributes nodes
    mix_mat = nx.attribute_mixing_matrix(G, 'degree') #generating the correlation matrix

    # plotting matrix
    
    plt.figure(figsize=(12,9))
    ax = sns.heatmap(mix_mat,vmin=0, vmax=np.max(mix_mat),cmap="YlGnBu")
    ax.invert_yaxis()
    ax.set_xlabel(r'$k_1$')
    ax.set_ylabel(r'$k_2$')
    plt.show()

# %%
#reading metabolic graph

g_metabolic = nx.readwrite.edgelist.read_edgelist('metabolic.edgelist.txt')

# %%
sns.kdeplot(list(dict(g_metabolic.degree()).values()))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
max(dict(g_metabolic.degree()).values())
# Out:
# 638

# %%
dcm_nx(g_metabolic)

# %% [markdown]
# #### Testing networkx function with a random network

# %%
#random network

g_random = nx.generators.random_graphs.erdos_renyi_graph(300,0.2)

# %%
sns.kdeplot(list(dict(g_random.degree()).values()))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
max(dict(g_random.degree()).values())
# Out:
# 79

# %%
dcm_nx(g_random)

# %% [markdown]
# Neste exercício, resolvi deixar as duas abordagens para fins comparativos.
#
# - A primeira abordagem utiliza a contagem dos graus dos vizinhos de cada nó de forma iterativa;
# - A segunda abordagem utiliza o networkx com a proposta sugerida pelo professor;
#
# + Um ponto de diferença foi no range dos valores dos eixos $x$ e $y$. Na primeira abordagem, os valores ficam mais fidedignos em relação aos graus dos nós, de acordo com a análise de distribuição de graus. Para a rede metabólica, percebe-se uma concentração de graus entre $0$ e $\approx 50$, mas há também nós com graus mais elevados. Por exemplo, há um nó com grau $638$, o grau máximo da rede. Na segunda abordagem utilizando networkx, os valores dos eixos vão até $48$ para a rede metabólica. Não entendi esse comportamento. O mesmo acontece para a rede aleatória Erdos Renyi. Na primeira abordagem, a concentração de graus está entre $\approx 40$ e $\approx 80$ e a matriz mostra essa concentração pela nuvem de correlação. Já na segunda abordagem com networkx, a matriz apresenta valores dos eixos até $35$.

# %% [markdown]
# ## Exercício 2 Page Rank

# %% [markdown]
# ### Trying newark network with networkx

# %%
#loading the network

g_n = nx.read_graphml('3649891_Newark.graphml')

# %%
#normalizing a list

def normalize_list(arr, t_min, t_max):
    #t_min and t_max control the range of nodes' sizes
    
    min_size = min(arr) #min of array
    max_size = max(arr) #max of array
    
    arr_ = t_min + ((arr - min_size) / (max_size - min_size)) * (t_max - t_min) #normalization
    return arr_

# %%
#calculating the page rank

g_n_pagerank = nx.pagerank_numpy(g_n) 
print(g_n_pagerank)
# Out:
# {'221508755': 0.0030097571448615915, '221508756': 0.0024532184446026057, '221508761': 0.0025843305411017343, '221508767': 0.002761822801082585, '221508771': 0.0039898086991207015, '221508785': 0.003163105979190446, '221508789': 0.0037935466726258626, '221508801': 0.0028752611473013704, '221509512': 0.00281720549232599, '221509520': 0.002829767728998172, '221509534': 0.002899774321647268, '221509941': 0.003854620397092686, '221509944': 0.001503891004722971, '221510076': 0.0027373805438349755, '221510079': 0.0028846380951609227, '221510083': 0.0028636909397668302, '221510091': 0.002487336883648261, '221510789': 0.0031707228588523702, '221510794': 0.002936117038846331, '221510937': 0.002773740512740574, '221510997': 0.002960715470049099, '221511007': 0.0028866034100692196, '221511011': 0.0028220581057080167, '221511111': 0.0028466309483477477, '221511591': 0.0029599520552349027, '221511597': 0.003855084141158009, '221511600': 0.002903758614992109, '221511612': 0.003936011002625846, '221511617': 0.0012481508969380366, '221511732': 0.003218437288188352, '221511735': 0.0013236391238667425, '221511874': 0.0029909651801941625, '221511878': 0.0020807914177351163, '221511923': 0.002830312542401125, '221520357': 0.0027410837282014367, '221520781': 0.004476197546966276, '221520787': 0.0016800045305204899, '221520790': 0.0016800045305204899, '221520839': 0.0027360376293587402, '221521206': 0.002863731696470384, '221521842': 0.0027645055169569156, '221521857': 0.002769321018720911, '221521873': 0.002763297427618689, '221522747': 0.002675537408766262, '221523121': 0.002778699376334773, '221523124': 0.0027670308819420647, '221523846': 0.003127966341824451, '221523860': 0.001503891004722971, '221525281': 0.0028325890067481844, '221525285': 0.0028827216904234484, '221525287': 0.002037269084830039, '221525369': 0.0036724322305528826, '221525394': 0.001704077919480568, '221525628': 0.002915790361726498, '221525648': 0.002718256902647015, '221526238': 0.0022743429444505333, '221526567': 0.003589979241474618, '221526641': 0.0014289093439645182, '221526715': 0.0015309239007783478, '221526740': 0.005266707491286134, '221526748': 0.0015309239007783478, '221526853': 0.0028964482547390894, '221526861': 0.002817628785437606, '221526873': 0.002793041031333329, '221526891': 0.0028176118633236667, '221526916': 0.00280185269001309, '221526943': 0.002748626377458821, '221526992': 0.002974327379438813, '221527000': 0.003150552265151261, '221535506': 0.0028907068331270047, '221535984': 0.0016337345464831287, '221536843': 0.002840845533305963, '221536847': 0.0028076649076540033, '221536882': 0.0029357853387584325, '221536886': 0.002869740934296004, '221537646': 0.003309511443380898, '221537652': 0.0013494434678379644, '221537740': 0.0027231195106406326, '221537774': 0.002711540808461987, '221537841': 0.0014865867827907058, '221540734': 0.0013126309473727171, '221540845': 0.0026053897860940397, '221540848': 0.0026071189165871363, '221540992': 0.0016847299209248213, '221542521': 0.0031361487518054895, '221542526': 0.003088839640713983, '221542559': 0.002931687933062863, '221542567': 0.0028098946070921104, '221542577': 0.0027619562931359798, '221542958': 0.0031974713744999843, '221542961': 0.0029509870820101764, '221543332': 0.0031919182426444234, '221543334': 0.0013161253942959646, '221544572': 0.0027364158270782248, '221544576': 0.0027624450754796855, '221544580': 0.002762951143800298, '221544661': 0.0036062106052413582, '221544665': 0.003484566044371504, '221544669': 0.002685363456317, '221544671': 0.0027429781418207345, '221544710': 0.003470125012188464, '221544717': 0.0034420290721086386, '221544799': 0.003523013257196318, '221544803': 0.0027008072647963467, '221544814': 0.002735698927021517, '221544827': 0.0022900555207935346, '221545143': 0.002701179201724214, '221545149': 0.00264925639597696, '221545152': 0.0033396771719350544, '221545154': 0.0026303863593345068, '221545156': 0.0025897981688205876, '221545162': 0.0033107880294594746, '221545165': 0.00318044 ...

# %%
#normalizing the page rank

norm_page = normalize_list(np.array(list(g_n_pagerank.values())),1,500)

# %%
sns.kdeplot(norm_page)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#plotting the page rank

plt.figure(figsize=(12,9))  
nx.draw(g_n, node_size=norm_page, node_color='red') #drawing the network
plt.title('PageRank')
# Out:
# Text(0.5, 1.0, 'PageRank')

# %%
#plotting the page rank

plt.figure(figsize=(12,9))  

#setting the color nodes following pagerank number
#pagerank below 150 is blue, above 150 is red
color_nodes = ['blue' if i<150 else 'red' for i in norm_page] 

nx.draw(g_n, node_size=norm_page, node_color=color_nodes) #drawing the network
plt.title('PageRank')
# Out:
# Text(0.5, 1.0, 'PageRank')

# %% [markdown]
# O tamanho dos nós no plot do networkx para a rede Newark não está tão bom. Conforme foi discutido com o professor, esta rede não é plotada pelo igraph. Tentei aumentar a proporcionalidade dos tamanhos, porém não consegui. Mesmo assim, é possível perceber a diferença no tamanho dos nós de acordo com o pagerank. No igraph, essa proporção é mais visível. Para dar mais destaque, plotei um gráfico diferenciando nós com pagerank acima de 150 (vermelho) e abaixo de 150 (azuis). Esse valor foi escolhido aleatoriamente.

# %% [markdown]
# ### Trying metabolic network with igraph

# %%
g_newark = ig.load('metabolic.edgelist.txt')

# %%
g_newark_pg = ig.Graph.pagerank(g_newark)
print(g_newark_pg)
# Out:
# [0.0010092378003682288, 0.00026476566882732976, 0.00026319183794389913, 0.0002671408182350321, 0.00026583097763362704, 0.0003756984495152689, 0.0002863909427470854, 0.0003974019983790828, 0.0011238321502822783, 0.0006081944927569257, 0.001609533771655763, 0.00023754109452991357, 0.00044123148746365185, 0.0003113127075657531, 0.0003111105875928599, 0.0003109412118734935, 0.0002912827692647515, 0.00026666195611765826, 0.00031029309496754826, 0.0002662501641564967, 0.00025406267160774755, 0.0002539553577156972, 0.00025385024925996934, 0.00024711987831490417, 0.0002451631860272581, 0.00025343612338075185, 0.00024478751331298885, 0.0004931452925563431, 0.00049833364615001, 0.0005049651505764604, 0.0007089962674373504, 0.0006991049737279125, 0.0006020116633025643, 0.000515801055060613, 0.00047819311564468997, 0.00016549024093859694, 0.00016549024093859694, 0.00016549024093859694, 0.00016549024093859694, 0.0003591111165233834, 0.0007329653634671687, 0.000768113823955694, 0.0005559944161484113, 0.0006037233478186116, 0.0006180301730621987, 0.0009562455094871131, 0.0009775883264430073, 0.00016549024093859694, 0.000870094516480048, 0.00016549024093859694, 0.0002469877705791482, 0.0004300190677472108, 0.0007007787646163815, 0.0003113127075656027, 0.00031111058759301013, 0.0003109412118734935, 0.00033817167086414203, 0.0002666619561175767, 0.00031029309496738867, 0.0002662501641564073, 0.0002540626716076919, 0.00025395535771563515, 0.0002538502492599116, 0.00029400877991412456, 0.0002451631860273043, 0.00025343612338075185, 0.00024478751331298885, 0.0012943684607522184, 0.000812842251223265, 0.001121953337211077, 0.000459260526301091, 0.00039857892557974123, 0.00026476566882719125, 0.00047161755040682403, 0.0005942741844164198, 0.00026723839062022225, 0.0008029691011469552, 0.00016549024093859694, 0.0004626484068227664, 0.00035566093278600213, 0.0007951605672794829, 0.001288693566947897, 0.002681657404273246, 0.0004911200686003482, 0.0009901722497126736, 0.00026782917263643035, 0.00026583097763362704, 0.0004855764783909037, 0.0003764849241003911, 0.0004059831761631396, 0.0003928323415753863, 0.0005349225897336221, 0.0004907584332522496, 0.00032096925922776935, 0.00021924759508712955, 0.000289944513461359, 0.0002863909427470854, 0.0004404918533065332, 0.00040905720977920133, 0.0004075431077826348, 0.0003066515914493624, 0.0003155580737821064, 0.0005004677415899406, 0.00036583298421013637, 0.0006817921103548566, 0.00016549024093859694, 0.00037826799305171963, 0.0002671408182350321, 0.0002631918379438373, 0.0003004660836557052, 0.00026866622781275703, 0.0004989121363449009, 0.00027421533489437424, 0.00041025198581160464, 0.0005890432937985351, 0.0003352089775149724, 0.00027421533489437424, 0.0005668338954374245, 0.0005240289647520429, 0.00033488628430969835, 0.0008581159750690394, 0.00027421533489437424, 0.0009586178618577403, 0.00046020957783899773, 0.0006162975475275677, 0.0003591111165233834, 0.0006768115742503758, 0.0006505337872954317, 0.0006428175878878178, 0.0003680900037485138, 0.00037039901120307855, 0.0009091444543357382, 0.0009101009952016401, 0.00037493102019677265, 0.0004145962297363959, 0.0009162783359629385, 0.0011786592286796905, 0.00036810034706973515, 0.0008872295697658856, 0.000916013639449401, 0.00040835722008568734, 0.000876174349633417, 0.0003591111165233834, 0.0004175710115297954, 0.0004892349323086924, 0.0005464340062382449, 0.0005516890750985794, 0.00044427251036294874, 0.0005866584555930855, 0.0005248283686402757, 0.0005066726053282429, 0.0003280414405644573, 0.00032843397183168115, 0.001133324055793938, 0.0011355747401842957, 0.0003292044133603626, 0.00033594749898239724, 0.001150109659622645, 0.0010454085884853558, 0.00032804319892877317, 0.001149486844296674, 0.001081759621511932, 0.00033488686734156636, 0.0010557473388473, 0.00033260382368601685, 0.00033645321188727515, 0.0016052243002527638, 0.0004928729157957673, 0.0008068519590762054, 0.00016549024093859694, 0.00027421533489437424, 0.0008553013595915178, 0.00 ...

# %%
g_newark_pg_norm = normalize_list(np.array(g_newark_pg),2,15)
g_newark_pg_norm
# Out:
# array([2.14623989, 2.0172066 , 2.01693382, ..., 2.01798755, 2.0600115 ,
#        2.04604672])

# %%
g_newark.vs["size"] = g_newark_pg_norm.tolist()
g_newark.vs["label_size"] = 2

# create plotting styles
visual_style = {}
visual_style["vertex_size"] = g_newark.vs["size"]
#visual_style["edge_width"] = 0.2
visual_style["layout"] = g_newark.layout_drl()
visual_style["bbox"] = (500, 500)
visual_style["margin"] = 30

ig.plot(g_newark, **visual_style)
